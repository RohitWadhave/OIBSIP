# %% [markdown]
# # **Author : ROHIT WADHAVE**
# ###  **Oasis Infobyte** - Data Science
# #####            *(FEBRUARY'22)*

# %% [markdown]
# # Task 2 : UNEMPLOYMENT ANALYSIS WITH PYTHON

# %% [markdown]
# ## **Read the csv dataset as a pandas dataframe.**

# %%
from google.colab import files
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-f66a7584-a7b8-4c52-9c53-9c606931e61e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f66a7584-a7b8-4c52-9c53-9c606931e61e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## **Importing all libraries required in this notebook**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

import seaborn as sns
sns.set_style('darkgrid')
sns.set(font_scale=1.4)

# %%
data = pd.read_csv(r"Unemployment in India.csv")

# %%
data1 = pd.read_csv(r"Unemployment_Rate_upto_11_2020.csv")

# %% [markdown]
# ## **Data Understanding**

# %%
pd.concat([data.head(),data.tail()])      # Show top 5 & bottom 5 rows  [data: Unemployment in India]
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# ...

# %%
pd.concat([data1.head(),data1.tail()])      # Show top 5 & bottom 5 rows   [data1: Unemployment_Rate_upto_11_2020]
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# ...

# %%
print(data.shape)
print(data1.shape)
# Out:
# (768, 7)
# (267, 9)

# %%
print(data.info)  # [data: Unemployment in India]
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
print(data1.info)   # [data1: Unemployment_Rate_upto_11_2020]
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
print('==============================================================================Unemployment in India==========================================================================================')
print()
print(data.describe())
print('==========================================================================Unemployment_Rate_upto_11_2020==========================================================================================')
print()
print(data1.describe())
# Out:
# ==============================================================================Unemployment in India==========================================================================================
#
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# ...

# %%
# This custom user defined function will give the datatype,count of null & non null values, count of Unique values present in dataset in the form of dataframe

def datainfo():
  df_temp = pd.DataFrame(index=data.columns)
  df_temp["Null value"] = data.isnull().sum()
  df_temp["% of the Null value"] = data.isnull().mean()*100
  df_temp["Not Null value"] = data.count()
  df_temp["Unique count"] = data.nunique()
  df_temp["Datatype"] = data.dtypes
  
  return df_temp

datainfo()                       #[data: Unemployment in India]
# Out:
#                                           Null value  % of the Null value  \
# Region                                            28             3.645833
#  Date                                             28             3.645833
#  Frequency                                        28             3.645833
#  Estimated Unemployment Rate (%)                  28             3.645833
#  Estimated Employed                               28             3.645833
#  Estimated Labour Participation Rate (%)          28             3.645833
# Area                                              28             3.645833
#
#                                           Not Null value  Unique count  \
# Region                                               740            28
#  Date                                                740            14
#  Frequency                                           740             2
#  Estimated Unemployment Rate (%)                     740           624
# ...

# %%
# This custom user defined function will give the datatype,count of null & non null values, count of Unique values present in dataset in the form of dataframe

def data1info():
  df_temp = pd.DataFrame(index=data1.columns)
  df_temp["Null value"] = data1.isnull().sum()
  df_temp["% of the Null value"] = data1.isnull().mean()*100
  df_temp["Not Null value"] = data1.count()
  df_temp["Unique count"] = data1.nunique()
  df_temp["Datatype"] = data1.dtypes
  
  return df_temp

data1info()                       # [data1: Unemployment_Rate_upto_11_2020]
# Out:
#                                           Null value  % of the Null value  \
# Region                                             0                  0.0
#  Date                                              0                  0.0
#  Frequency                                         0                  0.0
#  Estimated Unemployment Rate (%)                   0                  0.0
#  Estimated Employed                                0                  0.0
#  Estimated Labour Participation Rate (%)           0                  0.0
# Region.1                                           0                  0.0
# longitude                                          0                  0.0
# latitude                                           0                  0.0
#
#                                           Not Null value  Unique count  \
# Region                                               267            27
#  Date                                                267            10
# ...

# %%
data.isnull().value_counts()
# Out:
# Region   Date   Frequency   Estimated Unemployment Rate (%)   Estimated Employed   Estimated Labour Participation Rate (%)  Area
# False   False  False       False                             False                False                                     False    740
# True    True   True        True                              True                 True                                      True      28
# dtype: int64

# %%
data1.isnull().value_counts()
# Out:
# Region   Date   Frequency   Estimated Unemployment Rate (%)   Estimated Employed   Estimated Labour Participation Rate (%)  Region.1  longitude  latitude
# False   False  False       False                             False                False                                     False     False      False       267
# dtype: int64

# %%
print(data.dropna(inplace=True))
print(data1.dropna(inplace=True))
# Out:
# None
# None

# %%
print(data.shape)
print(data1.shape)
# Out:
# (740, 7)
# (267, 9)

# %%
print('==============================================================================Unemployment in India==========================================================================================')
print()
print(data.isnull().sum())
print('==========================================================================Unemployment_Rate_upto_11_2020==========================================================================================')
print()
print(data1.isnull().sum())
# Out:
# ==============================================================================Unemployment in India==========================================================================================
#
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64
# ==========================================================================Unemployment_Rate_upto_11_2020==========================================================================================
#
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
# ...

# %%
print(data.duplicated().sum())
print(data1.duplicated().sum())
# Out:
# 0
# 0

# %%
print(data.duplicated().value_counts())

#Check if the duplicate values are present in the dataset.
data[data.duplicated()]      # No duplicate value present in the dataset.
# Out:
# False    740
# dtype: int64
# Empty DataFrame
# Columns: [Region,  Date,  Frequency,  Estimated Unemployment Rate (%),  Estimated Employed,  Estimated Labour Participation Rate (%), Area]
# Index: []

# %%
print(data1.duplicated().value_counts())

#Check if the duplicate values are present in the dataset.
data1[data1.duplicated()]      # No duplicate value present in the dataset.
# Out:
# False    267
# dtype: int64
# Empty DataFrame
# Columns: [Region,  Date,  Frequency,  Estimated Unemployment Rate (%),  Estimated Employed,  Estimated Labour Participation Rate (%), Region.1, longitude, latitude]
# Index: []

# %%
plt.figure(figsize=(15,8))
sns.pairplot(data)        #[data: Unemployment in India]
sns.set(font_scale=0.7)

# %%
plt.figure(figsize=(15,8))
sns.pairplot(data1)          #[data1: Unemployment_Rate_upto_11_2020]
sns.set(font_scale=0.7)

# %%
plt.figure(figsize=(15,8))
plt.bar(data['Region'], data[' Estimated Unemployment Rate (%)'])
plt.xticks(rotation=90)
plt.xlabel('States')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment according to States')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.histplot(x=' Estimated Unemployment Rate (%)', data=data, kde=True, hue='Area')
plt.title('Unemployment according to Area')
plt.xlabel('Unemployment Rate')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(y=' Estimated Unemployment Rate (%)', x=' Date', data=data)
plt.title('Unemployment according to Date')
plt.xlabel('Date')
plt.xticks(rotation=90)
plt.ylabel('Unemployment Rate')
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.scatter(data1['Region.1'], data1[' Estimated Unemployment Rate (%)'])
plt.title('Unemployment according to Region')
plt.xlabel('Region')
plt.ylabel('Unemployment Rate')
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.bar(data['Region'], data[' Estimated Labour Participation Rate (%)'])
plt.xticks(rotation=90)
plt.xlabel('States', labelpad=14)
plt.ylabel('Labour Participation Rate', labelpad=14)
plt.title('Labour Participation according to States')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.histplot(x=' Estimated Labour Participation Rate (%)', data=data, kde=True, hue='Area')
plt.title('Labour Participation according to Area')
plt.xlabel('Labour Participation Rate')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(y=' Estimated Labour Participation Rate (%)', x=' Date', data=data)
plt.title('Labour Participation according to Date')
plt.xlabel('Date', labelpad=14)
plt.xticks(rotation=90)
plt.ylabel('Labour Participation Rate', labelpad=14)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.scatter(data1['Region.1'], data1[' Estimated Labour Participation Rate (%)'])
plt.title('Labour Participation according to Region')
plt.xlabel('Region')
plt.ylabel('Labour Participation Rate')
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.bar(data['Region'], data[' Estimated Employed'])
plt.xticks(rotation=90)
plt.xlabel('States', labelpad=14)
plt.ylabel('Employment Rate', labelpad=14)
plt.title('Employment according to States')
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.bar(data['Region'], data[' Estimated Employed'])
plt.xticks(rotation=90)
plt.xlabel('States', labelpad=14)
plt.ylabel('Employment Rate', labelpad=14)
plt.title('Employment according to States')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(y=' Estimated Employed', x=' Date', data=data)
plt.title('Employment according to Date')
plt.xlabel('Date', labelpad=14)
plt.xticks(rotation=90)
plt.ylabel('Employment Rate', labelpad=14)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.scatter(data1['Region.1'], data1[' Estimated Employed'])
plt.title('Employment according to Region')
plt.xlabel('Region', labelpad=14)
plt.ylabel('Employment Rate', labelpad=14)
plt.show()
